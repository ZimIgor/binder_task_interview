# %% [markdown]
# # Задачи
#
# 1. поле "Товарооборот группы" заполнить пропущенные занчения медианным значением
# 2. для "Типа локации - Спальный район" и "Гр20 - Свежие овощи" построить точечную диаграмму товарообората группы от потери рублевые (потери)
# 3. Для "Гр20 - Свежие овощи" построить матрицу корреляции для фичей "Тип локации", "Сезонность", "Кол-во позиций с продажами", "Товарооборот группы", "Остатки в шткуах/кг группы", "Потери рублевые (ПОТЕРИ)"

# %%
import pandas as pd
import seaborn as sns
import matplotlib as plt

# %%
df = pd.read_csv(r'Rto_gr_tt_itog_3.csv', delimiter=';')
df.head(5)
# Out:
# /var/folders/gm/fqtlcyc9181gmm2j1txnrsj00000gn/T/ipykernel_4363/2000240328.py:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r'/Users/igorzimenko/Downloads/Rto_gr_tt_itog_3.csv', delimiter=';')
#    ID месяца  ID торгового объекта             Тип локации  \
# 0     202405                  7124          Спальный район
# 1     202406               1025838                     NaN
# 2     202406                 43284   Спальный район+дорога
# 3     202404                786759   Спальный район+дорога
# 4     202405                 54163  Малый Населенный Пункт
#
#   Тип населенного пукта Сезонность магазина  Количество людей в НП  \
# 0                 Город             Обычный                96206.0
# 1                   NaN                 NaN                    NaN
# 2                 Город             Обычный               468842.0
# 3                 Город             Обычный               279174.0
# ...
